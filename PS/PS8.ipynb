# %% [markdown]
# # Instructions {-}
#
# 1. Download the provided jupyter notebook file to your computer.
# 2. Write all your answers and code into this notebook file.
# 3. When your work is completed, export your notebook to an HTML file.
# 4. Submit your HTML file and a copy of the notebook to the assignment page on Moodle.

# %% [markdown]
# ## Identification {-}
#
# ### Your Information {-}
#
# Your Last Name:
# Latrofa
#
# Your First Name:
# Ania
#
# ### Group Members (list any classmates you worked with on this problem set) {-}
#
# Your Group Members:

# %% [markdown]
# # Problem 0 - Introduction to Git/GitHub {-}
#
# Git is a version control system for tracking changes you make to files. Git allows for an easy way to manage and save updates to your files in one location.
#
# Git can be implemented in many forms, but GitHub is one of the most popular websites for hosting project repositories ("repos") and has become a staple in applied data science in collaborative settings.
#
# GitHub will give you (and collaborators) a much richer set of tools for tracking changes made in your code / analysis (or any project).
#
# GitHub also provides you an easy way to host your own website. In Friday's class next week, we will begin a setup towards building this kind of website. The course [PP434 - Automated Data Visualisation for Policymaking](https://www.lse.ac.uk/resources/calendar2024-2025/courseGuides/PP/2024_PP434.htm) works extensively to build and refine these websites over the full Autumn Term of course meetings. Below are some examples of this work from recent MPA-DSPP alumni.
#
# * [Educated Women and the Glass Ceiling: Breaking Through or Stuck?](https://giovanadelacruz.github.io/project.html)
# * [Mapping America's Rent Crisis](https://gmelmed.github.io/rent_project.html)

# %% [markdown]
# The goal of this problem is to have you complete preparatory work to download / install Git before next week's class. Specifically, you should complete the following steps.
#
# 1.  Identify and save in a common folder location any of your favorite visualisations that you have made in the course so far
# 2.  Create an account and repository on GitHub
# 3.  Download Git and the GitHub Command-Line Interface (CLI)

# %% [markdown]
# ## Step 1 - Identifying your favorite plots {-}
#
# One thing we can host on this website are any favorite plots you may have created. While you can host entire code bases on GitHub, for this exercise we will focus only on visualisations.
#
# In preparation for the activity, identify one to two of your favorite plots / visualisations you have made in the course to date and save those in a common folder on your computer you can access during next Friday's class. You should save each visualisation as a separate `.png` or `.jpeg` file if possible.

# %% [markdown]
# ## Step 2 - Creating a GitHub Account and Repository {-}
#
# These next steps guide you through setting up a basic GitHub account. While some of the installation paths can be frustrating, follow these steps as best you can. As usual for assistance during the setup process, I recommend frequent interactions with a GenAI tool as these models should be well trained for the general steps you will follow.
#
# ### Creating a GitHub Account {-}
#
# Visit [GitHub](https://github.com/) and create an account if you do not yet have one. You will need:
#
# * An __email address__. (it does not need to be your LSE email)
# * A __username__. This will be linked to your actual GitHub page so I recommend selecting a professional username.
#
# ### Creating your private repository {-}
#
# Follow the steps at this link to create a repository:
#
# [Quickstart for a repository](https://docs.github.com/en/repositories/creating-and-managing-repositories/quickstart-for-repositories)
#
# Note, when creating this repository, be sure to set your repository name to match the username you created. This will allow us to setup a [GitHub page](https://docs.github.com/en/pages/quickstart), which will be the website you can share publicly.
#
# For example, if my username is `CaseyKearney`, I would want to set my repository name to `CaseyKearney.github.io`
#
# For the other settings during setup, please:
#
# -   Set the visibility to __Public__ if you wish to share this material with external parties
# -   Select the toggle to 'Add README'
#
# You do not need to change anything in the 'Add .gitignore' or 'Add license' settings at this time.

# %% [markdown]
# ## Step 3 - Downloading Git and GitHub CLI {-}
#
# Ultimately we will want to interact with GitHub programmatically from the command line. To do this, you will need a separate download of the underlying programme `git`.
#
# ### Download Git {-}
#
# Download Git from [https://git-scm.com/](https://git-scm.com/)
#
# ### Install the GitHub CLI {-}
#
# Install the GitHub CLI from [https://cli.github.com/](https://cli.github.com/)

# %% [markdown]
# After completing these steps, you should have everything ready for our exercise. We will be interfacing with Git / GitHub from a terminal window in VS Code.
#
# __Optional__: If you would like to read now about Git in VS code, you may consult the overview at [Using Git source control in VS Code](https://code.visualstudio.com/docs/sourcecontrol/overview).

# %% [markdown]
# # Problem 1 - Predicting poverty and wealth from mobile phone metadata {-}

# %% [markdown]
# Read the provided paper "Predicting poverty and wealth from mobile phone metadata."[^1]
#
# After reading the paper, answer the following questions.
#
# [^1]: Blumenstock, Joshua, Gabriel Cadamuro, and Robert On. "Predicting poverty and wealth from mobile phone metadata." Science 350.6264 (2015): 1073-1076.

# %% [markdown]
# ## 1-A: Problem Statement {-}

# %% [markdown]
# What is the primary issue the paper seeks to address.

# %% [markdown]
# _Your explanation here:_
#
# The primary issued addressed by the paper is the scarcity of reliable quantitative data, which is a major challenge for policy-makers, with a specific focus on Rwanda.

# %% [markdown]
# ## 1-B: Methodology {-}

# %% [markdown]
# How do the authors' construct their measurement? How do they determine if their measure is accurate? How and why was machine learning used in this context?

# %% [markdown]
# _Your explanation here:_
#
# The authors construct the measurement through a two-step process: they survey 856 mobile subscribers with questions on asset ownership and housing; then they use feature engineering to transform phone call records into metrics, then select the most predictive features. They validate accuracy through cross-validation and comparison with government data—achieving strong correlations with Rwanda's official Demographic and Health Survey at district and cluster levels. Machine learning is essential because mobile phones are spreading in developing countries and capture behavioral patterns. They use supervised learning on the examples, test multiple algorithms, then scale predictions to all 1.5 million users to create wealth maps.

# %% [markdown]
# ## 1-C: External Validity {-}

# %% [markdown]
# This paper examined a small set of household measures of economic wellbeing in a single country. How easy do you think the results and methodology would be to transfer to a different environment? In other words, what possible threats to external validity may exist?

# %% [markdown]
# _Your explanation here:_
#
# External validity might be threatened by multiple factors, such as the difference in mobile phone usage and usage patterns across countries; the model was trained on Rwanda's specific wealth distribution and infrastructure; countries with different income inequality levels or economic structures might show different phone-wealth correlations; there might also be privacy differences in sharing anonymized data from cellphones.

# %% [markdown]
# ## 1-D: Summarizing the Findings {-}

# %% [markdown]
# In one crisp paragraph, summarize your key takeaways from this paper in language an intelligent but non-technical policy maker could understand.

# %% [markdown]
# _Your explanation here:_
#
# Traditional methods for measuring poverty and wealth in developing countries cost over $1 million and may take well over a year to be completed, leaving policymakers with outdated information. This research demonstrates that analyzing anonymized mobile phone records might help in predicting reliable individual and community wealth levels, at a lower cost and in less time. By surveying just 856 people and linking their responses to their phone usage, the researchers built a model that successfully estimated wealth for 1.5 million Rwandans and created detailed poverty maps down to village level—predictions, which matched official government statistics well. This approach could revolutionize how governments allocate resources and monitor economic progress in real-time, especially in regions where traditional data collection is expensive or not easy.

# %% [markdown]
# # Problem 2 - Civil War and Policy by p-value {-}
#
# During next week's classes we will continue to work with generalized linear models and binary predictions. One area in political science where these models have been used is studying the onset of international and civil conflict.
#
# We will discuss two major papers in this literature. This problem asks you to read and think about these papers to prepare for this discussion. All papers can be found on the Moodle page reading list under the __Autumn Term: Week Eleven__ header.
#
# ## 2-A: Fearon and Laitin {-}
#
# In a highly influential 2003 paper, James Fearon and David Laitin studied the onset of civil conflict.[^1] Since publication, this paper has been cited over 12,000 times.
#
# Our primary focus will be on a paper written in response to this original paper, but to help you better understand the context, you should read the abstract, introduction and conclusion of Fearon and Laitin 2003. Optionally, you may find it interesting to read the entire paper.
#
# After completing this reading, write 'Done' in the following box.
#
# [^1]: Fearon, James D., and David D. Laitin. "Ethnicity, insurgency, and civil war." American political science review 97.1 (2003): 75-90.

# %% [markdown]
# _Write Done Here:_
# Done

# %% [markdown]
# ## 2-B: Ward, Greenhill and Bakke {-}
#
# The original work by Fearon and Laitin generated many responses. This problem asks you to read and focus on one particular response from Ward, Greenhill and Bakke 2010.[^2] This paper is also available in the reading list for __Autumn Term: Week Eleven__.
#
# Read this paper. After you have finished, write 'Done' in the following box.
#
# [^2]: Ward, Michael D., Brian D. Greenhill, and Kristin M. Bakke. "The perils of policy by p-value: Predicting civil conflicts." Journal of peace research 47.4 (2010): 363-375.

# %% [markdown]
# _Write Done Here:_ Done

# %% [markdown]
# ## 2-C: Summarizing the Findings {-}
#
# Summarize the key arguments and response from Ward, Greenhill and Bakke (2010).
#
# Your summary should include an explanation and interpretation of the results presented in Table III.

# %% [markdown]
# _Your summary here:_
#
# The authors argue that conflict research has become dangerously fixated on statistical significance while neglecting predictive power. They contend that influential civil war models produce many statistically significant results but perform poorly at actually predicting when civil wars will occur.
#
# The authors demonstrate that variables can be statistically significant yet contribute little to predictive accuracy, and that highly parsimonious models can outperform complex models containing many "significant" variables. They argue that, until prediction becomes a standard evaluative tool, conflict research will remain stuck making broad statements about GDP and population without genuine theoretical progress.
#
# Table III reveals the limitations of the influential models when evaluated on their ability to correctly predict civil war onsets within their own datasets:
# At a 0.5 probability threshold, Fearon and Laitin's model predicted 0 out of 107 actual civil wars and
# Collier & Hoeffler's model predicted only 3 out of 46. Lowering the threshold to 0.3 improved performance slightly but introduced false positives—predicting wars that didn't happen.
# At a 0.1 threshold, both models captured more actual wars but at the cost of many false positives.

# %% [markdown]
# ## 2-D: Policy Applications {-}
#
# Describe another policy area where you think the critique from Ward, Greenhill, and Bakke (2010) may apply. Be specific about the issue area. Are there any steps that could be taken to mitigate these concerns? Please write your answer in the below field and also copy and paste your answer in the following [survey](https://moodle.lse.ac.uk/mod/questionnaire/view.php?id=1809668).

# %% [markdown]
# _Your explanation here:_
#
# It could be applied to the algorithmic risk assessment tools used by criminal justice systems, to predict reoffending, bail, sentencing, parole decisions. These tools identify statistically significant predictors, but have poor predictive accuracy. They risk generating too many false positives: many people predicted to reoffend, yet they would not.

# %%
from scipy.stats import binom
! jupyter nbconvert --to html PS8.ipynb --no-prompt
# Out:
# [NbConvertApp] Converting notebook PS8.ipynb to html
# [NbConvertApp] Writing 296463 bytes to PS8.html
